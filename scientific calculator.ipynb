# %%
def cal():
    print("This is your Basic Calculator.")
    print("""Instruction:
           1.Enter the first number
           2.Then enter the operation.
           3.Then choose the last number as asked by the program.
           The signs can be +, -, *, **, /, %
        """)



    num1 = int(input("Enter Number 1 "))
    sign = input("Enter Sign ")
    num2 = int(input("Enter Number 2 "))
  
    if sign == "+" or sign == "-" or sign == "*" or sign == "/":
        print("You want to calculate %s%s%s." % (num1, sign, num2))
    
    if sign == "+":
        result = int(num1) + int(num2)
        print("The result is %s." % (result))
      
    elif sign == "-":
        result = int(num1) - int(num2)
        print("The result is %s." % (result))
        
    elif sign == "*":
        result = num1 * num2
        print("The result is %s." % (result))

    elif sign == "/":
        result = num1 / num2
        print("The result is %s." % (result))
    
    elif sign == "**":
        result = num1**num2
        print("The result is %s." % (result))

    elif sign == "%":
        result = num1 % num2
        print("The result is %s." % (result))

    else:
        print("Sorry Something went wrong.")


# Square root function.
def sqr():
  

  from math import sqrt
    
  answer = input("Enter a number you want to find the square root of: ")
  def cals():
    result = sqrt(int(answer))
    print("The result is %s." % (result))

  print("We will now find the square root of you number.")

  if len(answer) > 0 and answer.isnumeric:
    cals()
  
  elif answer.isalpha:
    print("You can only use numbers.")

  elif len(answer) == 0:
    print("You must write something.")
  
  else:
    print("Something went wrong.")

# Vector length.
def length_vector():
  print("Enter the length of the x coordinate and the length of the y coodinate.")
  x1, y1 = input("x1 and y1 coordinate: ").split()
  x2, y2 = input("x2 and y2 coordinate: ").split()  
  print("Your vector is (%s, %s)" % (x1, y1))
  print("Your vector is (%s, %s)" % (x2, y2))
  
  
  x=float(x2)-float(x1)
  
  y=float(y2)-float(y1)
  
  from math import sqrt
  length = sqrt((x**2) + (y**2))
  print("The length of the vector is %s." % (length))  

# Cos, Sin and Tan...................................ye kya kiya hai??????..............exceptions and all look eg tan 90, inverse
def deg():
  
  degr, nummer = input("Enter cos, sin or tan and then the number: ").split()
  degr = degr.lower()
 
  import math
  
  if degr == "cos":
    result = math.cos(math.radians(int(nummer)))
    print("The result is %s" % (result))
  
  elif degr == "sin":
    result = math.sin(math.radians(int(nummer)))
    print("The result is %s" % (result))
  
  elif degr == "tan":
    result = math.tan(math.radians(int(nummer)))
    print("The result is %s" % (result))
  
  else:
    print("Something went wrong.")

def t_if():
  
    if choice == "basic calculator":
        cal()

    elif choice == "square root":
        sqr()

  
    elif choice == "vector length":
        length_vector()

 
    elif choice == "sin/cos/tan":
        deg()
  
    elif choice=="matrix add/sub":
        matrix_algebra()
    
    elif choice=="matrix mult" :
        matrix_mult()
  
    else:
        print("Something went wrong. Make sure you spelled correctly.")
    
    
def matrix(m,n):
    o=[]
    for i in range(m):
        row=[]
        for j in range(n):
            inp=int(input(f"Enter O[{i}][{j}]"))
            row.append(inp)
        o.append (row) 
        
    for i in range (m):
            for j in range(n):
                print(o[i][j],end=" ")
            print()     
    return o   
        
def sum(A,B):
    output=[]
    for i in range(len(A)):
        row=[]
        for j in range(len(A[0])):
            row.append(A[i][j]+B[i][j])
        output.append(row)
    return output

def diff(A,B):
    output=[]
    for i in range(len(A)):
        row=[]
        for j in range(len(A[0])):
            row.append(A[i][j]-B[i][j])
        output.append(row)
    return output


    return output

def matrix_algebra():
    
    m=int(input("Enter no of rows"))
    n=int(input("Enter number of columns"))

    print("Enter matrix A")
    A=matrix(m,n)

    print("Enter matrix B")
    B=matrix(m,n)

    op=input("Enter the operation to be performed: 'add ', 'sub','mult'")
    
    if op == "add":
        s=sum(A,B)
        for i in range (m):
            for j in range(n):
                print(s[i][j],end=" ")
            print()        
    
    elif op=="sub":
        s=diff(A,B)
        for i in range (m):
            for j in range(n):
                print(s[i][j],end=" ")
            print() 
            
            
def matrix_mult(): 
    m1=int(input("Enter rows for matrix1") )
    n1=int(input("Enter column for matrix1") )
    m2=int(input("Enter rows for matrix2") )
    n2=int(input("Enter column for matrix2") )
    
    if (n1==m2):
        A=matrix(m1,n1)
        B=matrix(m2,n2)
        
        import numpy as np
        C = np.zeros( (m1, n2) )
    
        for i in range(len(C)):
            for j in range(len(C[0])):
                for k in range(len(B)):
                    C[i][j]=C[i][j]+A[i][k]*B[k][j]
        
        for i in range (m1):
            for j in range(n2):
                print(C[i][j],end=" ")
            print()  
        
    else:
        print("Sorry not possible")
    
    
    
    
print("Enter what type of calculations you want.")
print("""You can choose 
                      'Basic Calculator' 
                      'Square root'
                      'Vector length'
                      'sin/cos/tan' 
                      'Matrix add/sub'
                      'Matrix mult'
                      'Polar rectangular'
                      
                      
                    
      """)

choice = input("Enter here: ").lower()

if len(choice) > 0:
    t_if()

else:
    print("Something went wrong. Make sure you spelled it correct.")
# Out:
# Enter what type of calculations you want.
# You can choose
#                       'Basic Calculator'
#                       'Square root'
#                       'Vector length'
#                       'sin/cos/tan'
#                       'Matrix add/sub'
#                       'Matrix mult'
#                       'Polar rectangular'
